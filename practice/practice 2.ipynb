# %%
from bs4 import BeautifulSoup
import requests, lxml, os, re
import pandas as pd
import numpy as np
import time
from termcolor import colored

import requests, random

# %%
user_agent_list = [
  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
  'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
]

# %%
def choose_agent(user_agent_list):
    user_agent = random.choice(user_agent_list)
    return user_agent

def extract_number(results_list:list) -> str:

    result_num = 0
    
    for term in results_list:
        selected_text = re.findall('about', term.lower())
        if selected_text:
            result_num = re.findall('about (.*) results', term.lower())[0]
            result_num = re.sub(',', '', result_num)
            result_num = int(result_num)

    return result_num

def scrape_number_of_results(phrase:str)->int:

    
    params = {"q": phrase, "hl": "en"}
    user_agent = choose_agent(user_agent_list)
    headers = {'User-Agent': user_agent}
    html = requests.get('https://scholar.google.com/scholar', headers=headers, params=params).text
 

    soup = BeautifulSoup(html, 'lxml')
    time.sleep(1)
        
    # the dictionary will be collected here
    results_list = []

    # Container where all needed dict_ is located
    for result in soup.select('.gs_ab_mdw'):
        results_list.append(result.text)

    result_num = extract_number(results_list)
    
    return result_num


def determine_node_size(phrases:list) -> dict:
    """
    get the list of phrases
    output a dictionary of their size (number of search results for each phrase)
    """
    sizes_dict = {}
    # single term search for size of node
    for phrase in phrases:
        print(phrase)
        sizes_dict[phrase] = scrape_number_of_results(phrase)
        print(sizes_dict[phrase])
    return sizes_dict


def create_graph(phrases):
    
    graph_ = {'nodes':[], 'links':[]}
    
    sizes_dict =  determine_node_size(phrases)

    
    # for nodes
    # {'nodes' : [{'id': , 'group':2 , 'size':name_freq[char]}]}
    for term, numb_ in sizes_dict.items():
        graph_['nodes'].append({'id': term, 'group': 1, "size":float(np.log(numb_)) })
    
    list_of_phrase_comb = []
    # combination of terms
    for i in range(len(phrases)):
        for j in range(len(phrases)):
            if i>j:
                new_phrase = "\"" + phrases[i] + "\"" + " AND " + "\"" + phrases[j] + "\""
                print(new_phrase)
                results_num = scrape_number_of_results(phrase=new_phrase)
                print(results_num)
    
                graph_['links'].append({'source': phrases[i], 
                                        'target': phrases[j],
                                        'value': float(results_num), 
                                        'color': float(results_num)})
    
    
    return graph_


graph_ = create_graph(phrases=['NLP', 'AI', 'decision support system', 
'healthcare', 'medicine', 'monitor', 'encode', 'alert', 'remind', 
'activity theory', 'decision making', 'HCI'])
# Out:
# NLP
# 0
# AI
# 0
# decision support system
# 0
# healthcare
# 0
# medicine
# 0
# monitor
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\mitra\Google-Scholar-search-term-analyzer\practice\practice 2.ipynb Cell 4 in <cell line: 87>()
#      <a href='vscode-notebook-cell:/c%3A/Users/mitra/Google-Scholar-search-term-analyzer/practice/practice%202.ipynb#ch0000003?line=77'>78</a>                 graph_['links'].append({'source': phrases[i],
#      <a href='vscode-notebook-cell:/c%3A/Users/mitra/Google-Scholar-search-term-analyzer/practice/practice%202.ipynb#ch0000003?line=78'>79</a>                                         'target': phrases[j],
#      <a href='vscode-notebook-cell:/c%3A/Users/mitra/Google-Scholar-search-term-analyzer/practice/practice%202.ipynb#ch0000003?line=79'>80</a>                                         'value': float(results_num),
# ...

# %%
i=4
import json
with open(f"C:\\Users\\mitra\\Google-Scholar-search-term-analyzer\\practice\\graph_{i}.json", 'w') as fp:
    json.dump(graph_, fp)
    i+=1

# %%
i=6
import json
with open(f"C:\\Users\\mitra\\Google-Scholar-search-term-analyzer\\practice\\graph_modified_{i}.json", 'w') as fp:
    json.dump(graph_modified, fp)
    i+=1

# %%
graph_
# Out:
# {'nodes': [{'id': 'NLP', 'group': 1, 'size': -inf},
#   {'id': 'AI', 'group': 1, 'size': -inf},
#   {'id': 'decision support system', 'group': 1, 'size': -inf},
#   {'id': 'healthcare', 'group': 1, 'size': -inf},
#   {'id': 'medicine', 'group': 1, 'size': -inf},
#   {'id': 'monitor', 'group': 1, 'size': -inf},
#   {'id': 'encode', 'group': 1, 'size': -inf},
#   {'id': 'alert', 'group': 1, 'size': -inf},
#   {'id': 'remind', 'group': 1, 'size': -inf},
#   {'id': 'activity theory', 'group': 1, 'size': -inf},
#   {'id': 'decision making', 'group': 1, 'size': -inf},
#   {'id': 'human computer interaction', 'group': 1, 'size': -inf}],
#  'links': [{'source': 'AI', 'target': 'NLP', 'value': 0.0, 'color': 0.0},
#   {'source': 'decision support system',
#    'target': 'NLP',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'decision support system',
#    'target': 'AI',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'healthcare', 'target': 'NLP', 'value': 0.0, 'color': 0.0},
# ...

# %%
import json
  
# Opening JSON file
f = open("C:\Dr. Ruhe\data_graph_5.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
graph_['links']
# Out:
# [{'source': 'decision support systems',
#   'target': 'natural language processing',
#   'value': 21700.0,
#   'color': 21700.0},
#  {'source': 'clinical setting',
#   'target': 'natural language processing',
#   'value': 3960.0,
#   'color': 3960.0},
#  {'source': 'clinical setting',
#   'target': 'decision support systems',
#   'value': 6530.0,
#   'color': 6530.0},
#  {'source': 'artificial intelligence',
#   'target': 'natural language processing',
#   'value': 0.0,
#   'color': 0.0},
#  {'source': 'artificial intelligence',
#   'target': 'decision support systems',
#   'value': 160000.0,
#   'color': 160000.0},
#  {'source': 'artificial intelligence',
#   'target': 'clinical setting',
#   'value': 21700.0,
#   'color': 21700.0},
#  {'source': 'healthcare',
#   'target': 'natural language processing',
#   'value': 63800.0,
#   'color': 63800.0},
#  {'source': 'healthcare',
#   'target': 'decision support systems',
#   'value': 107000.0,
#   'color': 107000.0},
# ...

# %%
graph_modified = graph_.copy()

max_ = max(item['value'] for item in graph_modified['links'])
min_ = min(item['value'] for item in graph_modified['links'])

def normalize(digit, min_=min_, max_=max_):
    normalized_d = (digit - min_) / (max_ - min_)
    return normalized_d

for item in graph_modified['links']:
    normalized = normalize(item['value'])
    item['value'] = normalized
    item['color'] = normalized

# %%
graph_modified
# Out:
# {'nodes': [{'id': 'natural language processing',
#    'group': 1,
#    'size': 15.191754583230663},
#   {'id': 'decision support systems', 'group': 1, 'size': 14.7862894751225},
#   {'id': 'clinical setting', 'group': 1, 'size': 15.49260711887219},
#   {'id': 'artificial intelligence', 'group': 1, 'size': 15.053884789007542},
#   {'id': 'healthcare', 'group': 1, 'size': 15.216693531577915}],
#  'links': [{'source': 'decision support systems',
#    'target': 'natural language processing',
#    'value': 0.043486973947895795,
#    'color': 0.043486973947895795},
#   {'source': 'clinical setting',
#    'target': 'natural language processing',
#    'value': 0.007935871743486974,
#    'color': 0.007935871743486974},
#   {'source': 'clinical setting',
#    'target': 'decision support systems',
#    'value': 0.01308617234468938,
#    'color': 0.01308617234468938},
#   {'source': 'artificial intelligence',
#    'target': 'natural language processing',
#    'value': 0.0,
#    'color': 0.0},
# ...

# %%
data['links']
# Out:
# [{'source': 'Ron', 'target': 'Harry', 'value': 1.0, 'color': 1.0},
#  {'source': 'Hermione',
#   'target': 'Harry',
#   'value': 0.5612903225806452,
#   'color': 0.5637583892617449},
#  {'source': 'Hermione',
#   'target': 'Ron',
#   'value': 0.5161290322580645,
#   'color': 0.5167785234899329},
#  {'source': 'Snape',
#   'target': 'Harry',
#   'value': 0.2645161290322581,
#   'color': 0.2483221476510067},
#  {'source': 'Snape',
#   'target': 'Ron',
#   'value': 0.07741935483870968,
#   'color': 0.08053691275167785},
#  {'source': 'Snape',
#   'target': 'Hermione',
#   'value': 0.07741935483870968,
#   'color': 0.08053691275167785},
#  {'source': 'Dudley',
#   'target': 'Harry',
#   'value': 0.3032258064516129,
#   'color': 0.30201342281879195},
#  {'source': 'Dudley',
#   'target': 'Ron',
#   'value': 0.0,
#   'color': 0.006711409395973154},
#  {'source': 'Dudley', 'target': 'Hermione', 'value': 0.0, 'color': 0.0},
# ...

# %%
graph_ = create_graph(phrases=['natural language processing', 'decision support systems', 'clinical setting', 'artificial intelligence' , 'healthcare'])
# Out:
# C:\Users\mitra\AppData\Local\Temp\ipykernel_20884\2097357067.py:11: RuntimeWarning: divide by zero encountered in log
#   graph_['nodes'].append({'id': term, 'group': 1, "size":float(np.log(numb_)) })
# "decision support systems" AND "natural language processing"
# "clinical setting" AND "natural language processing"
# "clinical setting" AND "decision support systems"
# "artificial intelligence" AND "natural language processing"
# "artificial intelligence" AND "decision support systems"
# "artificial intelligence" AND "clinical setting"
# "healthcare" AND "natural language processing"
# "healthcare" AND "decision support systems"
# "healthcare" AND "clinical setting"
# "healthcare" AND "artificial intelligence"

# %%
graph_
# Out:
# {'nodes': [{'id': 'natural language processing', 'group': 1, 'size': -inf},
#   {'id': 'decision support systems', 'group': 1, 'size': -inf},
#   {'id': 'clinical setting', 'group': 1, 'size': -inf},
#   {'id': 'artificial intelligence', 'group': 1, 'size': -inf},
#   {'id': 'healthcare', 'group': 1, 'size': -inf}],
#  'links': [{'source': 'decision support systems',
#    'target': 'natural language processing',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'clinical setting',
#    'target': 'natural language processing',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'clinical setting',
#    'target': 'decision support systems',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'artificial intelligence',
#    'target': 'natural language processing',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'artificial intelligence',
#    'target': 'decision support systems',
#    'value': 0.0,
#    'color': 0.0},
#   {'source': 'artificial intelligence',
# ...

# %%
# Out:
# ['ArticlesScholar', '']

# %%
params = {"q": "\"artificial intelligence\" AND \"natural language processing\"", "hl": "en"}
html = requests.get('https://scholar.google.com/scholar', headers=headers, params=params).text
#print(html)
soup = BeautifulSoup(html, 'lxml')

    
# the dictionary will be collected here
results_list = []

# Container where all needed dict_ is located
for result in soup.select('.gs_ab_mdw'):
    print(result)
    results_list.append(result.text)

result_num = extract_number(results_list)
# Out:
# <div class="gs_ab_mdw"><span class="gs_nph gs_nta">Articles</span><div class="gs_oph gs_ota">Scholar</div></div>
# <div class="gs_ab_mdw"></div>

# %%
result_num
# Out:
# 0

# %%
for result in soup.select('.gs_res_ccl_bot'):
    print(result)

# %%
soup.text
# Out:
# 'Google ScholarLoading...The system can\'t perform the operation now. Try again later.CiteAdvanced searchFind articleswith all of the wordswith the exact phrasewith at least one of the wordswithout the wordswhere my words occuranywhere in the articlein the title of the articleReturn articles authored bye.g., "PJ Hayes" or McCarthyReturn articles published ine.g., J Biol Chem or NatureReturn articles dated between\xa0—\xa0e.g., 1996Saved to My libraryDoneRemove articleArticlesCase lawProfilesMy profileMy libraryAlertsMetricsAdvanced searchSettingsSign inSign inArticlesScholarMy profileMy libraryYearAny timeSince 2022Since 2021Since 2018Sort by relevanceSort by dateAny typeReview articlesinclude patentsinclude citationsPlease show you\'re not a robotSorry, we can\'t verify that you\'re not a robot when JavaScript is turned off.Please enable JavaScript in your browser and reload this page.HelpPrivacyTerms'

# %%
soup.find_all("a")
# Out:
# [<a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_ia_notf"></span><span class="gs_lbl"></span></a>,
#  <a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_asd" href="javascript:void(0)" id="gs_asd-x" role="button"><span class="gs_ico"></span><span class="gs_ia_notf"></span><span class="gs_lbl"></span></a>,
#  <a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_md_albl-d" href="javascript:void(0)" id="gs_md_albl-d-x" role="button"><span class="gs_ico"></span><span class="gs_ia_notf"></span><span class="gs_lbl"></span></a>,
# ...

# %%
soup.find_all("div", {"class": "gs_res_ccl"})
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
